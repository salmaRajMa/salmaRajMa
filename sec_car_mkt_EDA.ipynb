# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


import seaborn as sns
sns.set()  #  Will import Seaborn functionalities
# we don't like warnings
# you can comment the following 2 lines if you'd like to
import warnings
warnings.filterwarnings('ignore')

# %%
# Disply all Columns
pd.options.display.max_columns=70

# %%
sec_car = pd.read_csv('secondary_car_market.csv')
sec_car.head()
# Out:
#   maker model   mileage  manufacture_year transmission door_count seat_count  \
# 0  audi    a8  136702.0            2006.0         auto        4.0        5.0
# 1  audi    a3  102526.0            2004.0          man          4          5
# 2  audi    a3     684.0            2016.0         auto        5.0        5.0
# 3  audi    s7   38525.0            2013.0         auto        5.0        4.0
# 4  audi    a1   45006.0            2010.0          man          3          4
#
#    displacement  horse_power    price
# 0          3.94        271.0  12285.0
# 1          1.97        138.0   5500.0
# 2          1.97        148.0  39649.0
# 3          3.99        414.0  64233.0
# 4          1.60        103.0  16848.0

# %%
#sec_car = sec_car.drop('Unnamed: 0', axis = 1)

# %%
sec_car.shape
# Out:
# (300000, 10)

# %%
sec_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   maker             300000 non-null  object
#  1   model             300000 non-null  object
#  2   mileage           300000 non-null  float64
#  3   manufacture_year  300000 non-null  float64
#  4   transmission      300000 non-null  object
#  5   door_count        300000 non-null  object
#  6   seat_count        300000 non-null  object
#  7   displacement      300000 non-null  float64
#  8   horse_power       300000 non-null  float64
#  9   price             300000 non-null  float64
# dtypes: float64(5), object(5)
# memory usage: 22.9+ MB

# %%
sec_car['door_count'].unique()
# Out:
# array(['4.0', '4', '5.0', '3', 'None', '2', '2.0', '3.0', '5', '7.0', '7',
#        '6', '6.0', '1.0', '1', 4.0, 5.0, 3.0, 2.0, 6.0, 7.0, 1.0],
#       dtype=object)

# %%
sec_car['door_count'].value_counts()
# Out:
# 5.0     78074
# 4.0     66996
# 4       55832
# 2.0     17272
# 4.0     16394
# 5.0     15652
# 2       15020
# 3.0     12545
# 5        8927
# None     6149
# 2.0      3470
# 3.0      2320
# 3        1239
# 6.0        70
# 6.0        17
# 6          13
# 7.0         4
# 7.0         2
# 1.0         1
# 1           1
# 7           1
# 1.0         1
# Name: door_count, dtype: int64

# %%
sec_car['door_count'].value_counts(normalize=True)
# Out:
# 5.0     0.260247
# 4.0     0.223320
# 4       0.186107
# 2.0     0.057573
# 4.0     0.054647
# 5.0     0.052173
# 2       0.050067
# 3.0     0.041817
# 5       0.029757
# None    0.020497
# 2.0     0.011567
# 3.0     0.007733
# 3       0.004130
# 6.0     0.000233
# 6.0     0.000057
# 6       0.000043
# 7.0     0.000013
# 7.0     0.000007
# 1.0     0.000003
# 1       0.000003
# 7       0.000003
# 1.0     0.000003
# Name: door_count, dtype: float64

# %%
sec_car['seat_count'].value_counts(normalize=True)
# Out:
# 5.0     0.466743
# 5       0.203987
# 5.0     0.102447
# 4.0     0.064487
# None    0.035087
# 4       0.032913
# 7.0     0.029920
# 4.0     0.010710
# 7.0     0.008293
# 2.0     0.008277
# 7       0.008030
# 3.0     0.005160
# 2       0.004650
# 9.0     0.003713
# 6.0     0.003333
# 3       0.003043
# 2.0     0.001743
# 9       0.001683
# 8.0     0.001483
# 9.0     0.000880
# 6.0     0.000860
# 6       0.000810
# 3.0     0.000750
# 8.0     0.000477
# 8       0.000350
# 17.0    0.000023
# 1.0     0.000020
# 1.0     0.000017
# 17      0.000017
# 10      0.000017
# 12.0    0.000010
# 15.0    0.000010
# 10.0    0.000010
# 13.0    0.000007
# 14      0.000007
# 1       0.000007
# 18.0    0.000007
# 74.0    0.000003
# 55.0    0.000003
# 10.0    0.000003
# 18      0.000003
# 57.0    0.000003
# 20      0.000003
# Name: seat_count, dtype: float64

# %%
print(sec_car.nunique())
# Out:
# maker                   3
# model                 105
# mileage             67879
# manufacture_year      123
# transmission            2
# door_count             22
# seat_count             43
# displacement          407
# horse_power           341
# price               32322
# dtype: int64

# %%
sec_car['manufacture_year'].value_counts()
# Out:
# 2015.0    52417
# 2012.0    30429
# 2011.0    26476
# 2014.0    21986
# 2013.0    18937
#           ...
# 1597.0        1
# 1589.0        1
# 392.0         1
# 381.0         1
# 1009.0        1
# Name: manufacture_year, Length: 123, dtype: int64

# %%
# Disply all Columns
pd.options.display.max_rows=170

# Finding missing values

sec_car.isna().sum()
# Out:
# maker               0
# model               0
# mileage             0
# manufacture_year    0
# transmission        0
# door_count          0
# seat_count          0
# displacement        0
# horse_power         0
# price               0
# dtype: int64

# %%
sec_car['model'].value_counts()
# Out:
# golf         32427
# a3           28055
# focus        27790
# fiesta       17915
# passat       15220
#              ...
# orion            5
# taurus           4
# routan           2
# excursion        2
# contour          1
# Name: model, Length: 105, dtype: int64

# %%
sec_car.columns
# Out:
# Index(['maker', 'model', 'mileage', 'manufacture_year', 'transmission',
#        'door_count', 'seat_count', 'displacement', 'horse_power', 'price'],
#       dtype='object')

# %%
sec_car['maker'].value_counts()
# Out:
# ford          100000
# volkswagen    100000
# audi          100000
# Name: maker, dtype: int64

# %%
sec_car.shape
# Out:
# (300000, 10)

# %%
len(sec_car)
# Out:
# 300000

# %%
sec_car.describe().transpose()
# Out:
#                      count          mean           std    min       25%  \
# mileage           300000.0  63739.228950  86288.411138   0.00  15992.00
# manufacture_year  300000.0   2009.096253     16.946915  39.00   2006.00
# displacement      300000.0      1.876543      0.904341   0.01      1.56
# horse_power       300000.0    136.943660     63.155779  13.00    101.00
# price             300000.0  16605.141743  59581.096613   0.00   4797.00
#
#                       50%       75%          max
# mileage           55914.0  96934.00   6213709.00
# manufacture_year   2011.0   2014.00      2017.00
# displacement          1.9      1.98        32.77
# horse_power         123.0    154.00      1337.00
# price             13455.0  23271.00  30420000.00

# %%
type(None) #(Object)
# Out:
# NoneType

# %%
# sec_car_dtype = pd.DataFrame(index=sec_car.index, columns=sec_car.columns)
# for rowindex in range(sec_car.shape[5]):
#     for columnindex in range (sec_car.shape[6]):
#         sec_car_dtype.iloc[rowindex,columnindex] = str(type(sec_car.iloc[rowindex,columnindex]))
#         sec_car_dtype

# %%
sec_car.describe(include=['object', 'bool'])
# Out:
#              maker   model transmission door_count seat_count
# count       300000  300000       300000     300000     300000
# unique           3     105            2         22         43
# top     volkswagen    golf          man        5.0        5.0
# freq        100000   32427       219799      78074     140023

# %%
#For categorical (type object) and boolean (type bool) features we can use the value_counts method

# %%
sec_car['maker'].value_counts()
# Out:
# volkswagen    100000
# audi          100000
# ford          100000
# Name: maker, dtype: int64

# %%
sec_car['model'].value_counts()
# Out:
# golf               32427
# a3                 28055
# focus              27790
# fiesta             17915
# passat             15220
# a4                 13803
# mondeo             13580
# polo               11514
# a6                  9178
# c-max               7850
# touran              7413
# a1                  7000
# a5                  6731
# q5                  5548
# kuga                5126
# q3                  4563
# s-max               4547
# galaxy              4501
# tiguan              4347
# ka                  4320
# caddy               4039
# transit             3781
# coupe               3526
# q7                  3338
# sharan              3045
# a8                  2626
# multivan            2436
# golf-sportsvan      2342
# tt                  2291
# fusion              2242
# golf-plus           2187
# touareg             2069
# up                  2002
# b-max               1945
# transporter         1677
# a6-allroad          1615
# grand-c-max         1478
# ...

# %%
(sec_car['maker'].value_counts().plot(
        kind='bar',
        figsize=(8, 6),
        title='Distribution of Maker',
    )
);
plt.show()

# %%
(sec_car['model'].value_counts().plot(
        kind='bar',
        figsize=(20, 10),
        title='Distribution of Model',
    )
);
plt.show()

# %%
(sec_car['door_count'].value_counts().plot(
        kind='bar',
        figsize=(8, 6),
        title='Distribution of Door Count',
    )
);
plt.show()

# %%
(sec_car['seat_count'].value_counts().plot(
        kind='bar',
        figsize=(20, 10),
        title='Distribution of Seat Count',
    )
);
plt.show()

# %%
sec_car[sec_car['price'] == 1].mean()
# Out:
# maker              NaN
# model              NaN
# mileage            NaN
# manufacture_year   NaN
# transmission       NaN
# door_count         NaN
# seat_count         NaN
# displacement       NaN
# horse_power        NaN
# price              NaN
# dtype: float64

# %%
#1.1.1 Histograms and density plots

# %%
features = ['mileage', 'manufacture_year', 'door_count', 'seat_count','displacement','horse_power', 'price']

sec_car[features].hist(figsize=(20, 10));

# %%
sec_car[features].plot(kind='density', subplots=True, layout=(4, 4), 
                  sharex=False, figsize=(20, 20));

# %%
# increasing the width of the Chart
import seaborn as sns
plt.rcParams['figure.figsize'] = 10,10 # similar to par(mfrow = c(2,1), mar = c(4,4,2,1)) # 2 columns and 1 row
sns.distplot(sec_car["price"]) # pass it one variable

# if you are getting warnings related to the package you should use ignore function
import warnings
warnings.filterwarnings ('ignore')

# %%
_, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 7))

sns.countplot(x='maker', data=sec_car, ax=axes[0]);
sns.countplot(x='transmission', data=sec_car, ax=axes[1]);

# %%
# Distributions of categorical features
plt.rcParams['figure.figsize'] = 8,6
sns.countplot(y='maker', data=sec_car)
plt.show()

sns.countplot(y='transmission', data=sec_car)
plt.show()

# %%
# Calculate Correlation
corr_matrix = sec_car.corr()  # corr(autinsurance)
corr_matrix
# Out:
#                    mileage  manufacture_year  displacement  horse_power  \
# mileage           1.000000         -0.146711      0.117333    -0.037132
# manufacture_year -0.146711          1.000000     -0.082326     0.049929
# displacement      0.117333         -0.082326      1.000000     0.538853
# horse_power      -0.037132          0.049929      0.538853     1.000000
# price            -0.082782          0.047488      0.066363     0.164605
#
#                      price
# mileage          -0.082782
# manufacture_year  0.047488
# displacement      0.066363
# horse_power       0.164605
# price             1.000000

# %%
#Correlation heatmap of the numberic variables
plt.rcParams['figure.figsize'] = 20,10  # control plot sizeimport seaborn as sns
sns.heatmap(sec_car.corr())
# Out:
# <AxesSubplot:>

# %%
# Correlation with Target Variable
sec_car.corr()['price'].plot()
# Out:
# <AxesSubplot:>

# %%
#Pandas scatter matrix function helps visualize the relationship between features
from pandas.plotting import scatter_matrix
p=scatter_matrix(sec_car, alpha=0.2, figsize=(30, 20), diagonal='kde')

# %%
# Box and Whisker Plots
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 20,20  # control plot size
sec_car.plot(kind='box', subplots=True, layout=(6,6), sharex=False, sharey=False)
plt.show()

# %%
# Univariate Density Plots
plt.rcParams['figure.figsize'] = 20,20  # control plot size

sec_car.plot(kind='density', subplots=True, layout=(6,6), sharex=False)
plt.show()

# %%
# Univariate Histograms
plt.rcParams['figure.figsize'] = 20,20  # control plot size

sec_car.hist()
plt.show()

# %%
#Scatter Plot
plt.rcParams['figure.figsize'] = 5,5

plt.scatter(sec_car['displacement'], sec_car['horse_power']);

# %%
sns.jointplot(x='model', y='price', 
              data=sec_car, kind='scatter');

# %%
sns.jointplot('displacement', 'horse_power', data=sec_car,
              kind="kde", color="g");

# %%
# `pairplot()` may become very slow with the SVG format
# %config InlineBackend.figure_format = 'png'
sns.pairplot(sec_car);

# %%
# ! pip install pandas_profiling

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(sec_car, title='Pandas Profiling Report', explorative=True)

# %%
profile
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.9.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-09-14 23:06:29.058540&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# Import Libraries
print('Importing Libraries ... ',end='')
import sweetviz as sv
import pandas as pd
print('Done')
# Out:
# Importing Libraries ... Done

# %%
# Analyzing data
report=sv.analyze(sec_car)

# Generating report
report.show_html('eda_report.html')
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-0e9817e1180e> in <module>
#       1 # Analyzing data
# ----> 2 report=sv.analyze(sec_car)
#       3
#       4 # Generating report
#       5 report.show_html('eda_report.html')
#
# ~\anaconda3\lib\site-packages\sweetviz\sv_public.py in analyze(source, target_feat, feat_cfg, pairwise_analysis)
#      10             feat_cfg: FeatureConfig = None,
#      11             pairwise_analysis: str = 'auto'):
# ---> 12     report = sweetviz.DataframeReport(source, target_feat, None,
#      13                                       pairwise_analysis, feat_cfg)
#      14     return report
#
# ~\anaconda3\lib\site-packages\sweetviz\dataframe_report.py in __init__(self, source, target_feature_name, compare, pairwise_analysis, fc)
#     252             # start = time.perf_counter()
# ...

# %%
report.show_html(filepath='eda_report.html',
open_browser=True,
layout='vertical',
scale=0.7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-8bb97ca91792> in <module>
# ----> 1 report.show_html(filepath='eda_report.html',
#       2 open_browser=True,
#       3 layout='vertical',
#       4 scale=0.7)
#
# NameError: name 'report' is not defined

# %%
report.show_notebook(w=None, 
                h=None, 
                scale=None,
                layout='vertical',
                filepath='sweetviz_report.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-0214b1144e5c> in <module>
# ----> 1 report.show_notebook(w=None,
#       2                 h=None,
#       3                 scale=None,
#       4                 layout='vertical',
#       5                 filepath='sweetviz_report.html')
#
# NameError: name 'report' is not defined
